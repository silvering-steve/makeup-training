# %%
from ultralytics import YOLO

# %%
model = YOLO("models/training_new_v1/weights/best.pt")

# %%
model.train(
    model="models/training_new_v1/weights/best.pt",
    data="datasets/data.yaml",
    epochs=5000,
    patience=200,
    batch=32,
    imgsz=256,
    project="models",
    name="training_new_v1",
    exist_ok=True,
    optimizer='auto',
    resume=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.0.208 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.207  Python-3.10.4 torch-2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...
